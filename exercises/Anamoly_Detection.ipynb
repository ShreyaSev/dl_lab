# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.models import Sequential

from keras.layers import Dense,Conv2D,Conv2DTranspose,Input,MaxPool2D

from keras.datasets import mnist
from keras.datasets import fashion_mnist

# %%
(x_train_m,_),(x_test_m,_) = mnist.load_data()
(x_train_f,_),(x_test_f,_) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print(f"xtrain_fashion_shape:{x_train_f.shape}\nxtrain_mnist_shape:{x_train_m.shape}")
# Out:
# xtrain_fashion_shape:(60000, 28, 28)
# xtrain_mnist_shape:(60000, 28, 28)

# %%
x_train_f = x_train_f.reshape(60000,28,28,1)
x_train_m = x_train_m.reshape(60000,28,28,1)

x_test_f = x_test_f.reshape(10000,28,28,1)
x_test_m = x_test_m.reshape(10000,28,28,1)

# %%
x_train_f = x_train_f / 255.0
x_test_f = x_test_f / 255.0

x_train_m = x_train_m / 255.0
x_test_m = x_test_m / 255.0

# %%
def create_model():
  model = Sequential()
  model.add(Input(shape=(28,28,1)))
  model.add(Conv2D(32,(3,3),activation='relu',padding='same'))
  model.add(MaxPool2D(2,2))
  model.add(Conv2D(32,(3,3),activation='relu',padding='same'))
  model.add(MaxPool2D(2,2))

  model.add(Conv2DTranspose(32,(3,3),strides=2,padding='same',activation='relu'))
  model.add(Conv2DTranspose(32,(3,3),strides=2,padding='same',activation='relu'))
  model.add(Conv2D(1,(3,3),activation='sigmoid',padding='same'))

  return model

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 32)        9248
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        9248
#  Transpose)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)         289
#
# ...
# Total params: 28353 (110.75 KB)
# Trainable params: 28353 (110.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy')

# %%
history = model.fit(x_train_f,x_train_f,epochs=10,validation_data=(x_test_f,x_test_f))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 21s 5ms/step - loss: 0.2759 - val_loss: 0.2631
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2571 - val_loss: 0.2570
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2535 - val_loss: 0.2546
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2520 - val_loss: 0.2536
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2512 - val_loss: 0.2529
# Epoch 6/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2507 - val_loss: 0.2525
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2503 - val_loss: 0.2521
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2500 - val_loss: 0.2519
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2497 - val_loss: 0.2517
# Epoch 10/10
# ...
